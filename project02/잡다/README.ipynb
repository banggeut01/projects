# %% [markdown]
# #  파이썬을 활용한 데이터 수집 II

# %% [markdown]
# ## 요구사항
# 1. 네이버 영화 검색 API - `movie_naver.py`
# * project01에서 얻은 `movie.csv`의 `영화명(국문)`을 바탕으로 네이버 영화 검색 API를 통해 추가적 데이터 수집. 해당 데이터는 기준 평점 및 영화 썸네일로 활용될 것.
#
#
#     * 요청
#         * 필수 요청변수 query: `영화명(국문)`으로 요청
#
#
#     * 응답
#         * movie.csv파일의 `영진위 영화 대표코드`, link: `하이퍼텍스트 link`, image: `영화 썸네일 이미지 URL`, userRating: `유저 평점`
#         * `영화 썸네일 이미지 URL`이 없으면 저장하지 않기.
#         * **movie_naver.csv**에 저장하기
#
#
# [소스보기](./movie_naver.py)

# %%
# API URL로 요청 후 응답 받아오기

import requests
from decouple import config
import pprint

# 네이버 API 설정
client_id = config('NAVER_CLIENT_ID')
client_secret = config('NAVER_CLIENT_SECRET')

# 헤더 설정
headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret
}

# 요청
api_url = 'https://openapi.naver.com/v1/search/movie.json'
# 실제 코드에서는 query를 movie.csv에서 받아와야한다.
query = '자전차왕 엄복동'

response = requests.get(f'{api_url}?query={query}', headers=headers).json()
pprint.pprint(response)
# Out:
# {'display': 1,
#  'items': [{'actor': '비|강소라|이범수|',
#             'director': '김유성|',
#             'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1590/159070_P13_114738.jpg',
#             'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=159070',
#             'pubDate': '2018',
#             'subtitle': 'Race to Freedom : Um Bok Dong',
#             'title': '<b>자전차왕 엄복동</b>',
#             'userRating': '3.84'}],
#  'lastBuildDate': 'Fri, 26 Jul 2019 10:01:01 +0900',
#  'start': 1,
#  'total': 1}

# %% [markdown]
# client_id와 client_secret 처럼 노출되지 말아야하는 정보는 .env 파일(환경변수 파일)을 통해 관리. .env는 .gitignore에 넣어주어 git이 접근하지 못하게 해야함.

# %%
# movie.csv에서 query에 넣어줄 영화명(국문) 가져오기

with open('movie.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        pprint.pprint(row)
        break
# Out:
# OrderedDict([('영화 대표코드', '20196309'),
#              ('영화명(국문)', '스파이더맨: 파 프롬 홈'),
#              ('영화명(영문)', 'Spider-Man: Far From Home'),
#              ('영화명(원문)', ''),
#              ('관람등급', '12세이상관람가'),
#              ('개봉연도', '20190702'),
#              ('상영시간', '129'),
#              ('장르', '액션'),
#              ('감독', '존 왓츠')])

# %%
# 영화명(국문)
row.get('영화명(국문)')
# Out:
# '스파이더맨: 파 프롬 홈'

# %%
# link, image userRating 값 추출하기

response.get('items') # 리스트 안에 딕셔너리가 포함된 형태
# Out:
# [{'title': '<b>자전차왕 엄복동</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=159070',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1590/159070_P13_114738.jpg',
#   'subtitle': 'Race to Freedom : Um Bok Dong',
#   'pubDate': '2018',
#   'director': '김유성|',
#   'actor': '비|강소라|이범수|',
#   'userRating': '3.84'}]

# %%
print(response.get('items')[0].get('link'))
print(response.get('items')[0].get('image'))
print(response.get('items')[0].get('userRating'))
# Out:
# https://movie.naver.com/movie/bi/mi/basic.nhn?code=159070
# https://ssl.pstatic.net/imgmovie/mdi/mit110/1590/159070_P13_114738.jpg
# 3.84

# %%
# movies 리스트에 영화 코드, 링크, 이미지, 평점 딕셔너리 형태로 삽입

movies = []

temp = {
    # movieCd 추가하기
    'link': response.get('items')[0].get('link'),
    'image': response.get('items')[0].get('image'),
    'userRating': response.get('items')[0].get('userRating')
}

movies.append(temp)

# %%
# 결과 movie_naver.csv에 저장하기

import csv

with open('movie_naver.csv', 'w', encoding='utf-8') as f:
    # 영화 대표 코드 'movieCd' 추가하기
    fieldnames = ['link', 'image', 'userRating']
    csv_writer = csv.DictWriter(f, fieldnames=fieldnames)
    csv_writer.writeheader()
    for movie in movies:
        csv_writer.writerow(movie)

# %%
# 결과 파일 확인하기

with open('movie_naver.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        pprint.pprint(row)
# Out:
# OrderedDict([('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=159070'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1590/159070_P13_114738.jpg'),
#              ('userRating', '3.84')])

# %% [markdown]
# 코드 완성 후 실제 movie_naver.csv 결과

# %%
with open('movie_naver.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    count = 0
    for row in reader:
        pprint.pprint(row)
        count += 1
    print(f'movie_naver.csv {count}개의 행')
# Out:
# OrderedDict([('movieCd', '20196309'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=173123'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1731/173123_P06_135928.jpg'),
#              ('userRating', '8.37')])
# OrderedDict([('movieCd', '20183867'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=163788'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1637/163788_P18_105943.jpg'),
#              ('userRating', '9.43')])
# OrderedDict([('movieCd', '20184047'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=101966'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1019/101966_P09_114632.jpg'),
#              ('userRating', '9.09')])
# OrderedDict([('movieCd', '20185353'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180209'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1802/180209_P42_134851.jpg'),
#              ('userRating', '5.91')])
# OrderedDict([('movieCd', '20183782'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=161967'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1619/161967_P80_151640.jpg'),
#              ('userRating', '8.50')])
# OrderedDict([('movieCd', '20185986'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174834'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1748/174834_P53_105510.jpg'),
#              ('userRating', '7.38')])
# OrderedDict([('movieCd', '20191601'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183783'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1837/183783_P16_105340.jpg'),
#              ('userRating', '4.08')])
# OrderedDict([('movieCd', '20199951'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183850'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1838/183850_P16_113434.jpg'),
#              ('userRating', '6.74')])
# OrderedDict([('movieCd', '20196655'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181698'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1816/181698_P38_102749.jpg'),
#              ('userRating', '8.27')])
# OrderedDict([('movieCd', '20192151'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=182014'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1820/182014_P09_102330.jpg'),
#              ('userRating', '6.92')])
# OrderedDict([('movieCd', '20198453'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=179125'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1791/179125_P44_162751.jpg'),
#              ('userRating', '7.64')])
# OrderedDict([('movieCd', '20190273'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183836'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1838/183836_P33_161902.jpg'),
#              ('userRating', '8.75')])
# OrderedDict([('movieCd', '20182585'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=179875'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1798/179875_P37_142918.jpg'),
#              ('userRating', '5.57')])
# OrderedDict([('movieCd', '20192591'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183666'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1836/183666_P01_135734.jpg'),
#              ('userRating', '0.00')])
# OrderedDict([('movieCd', '20192022'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167633'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167633_P18_100754.jpg'),
#              ('userRating', '6.91')])
# OrderedDict([('movieCd', '20196657'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=97631'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0976/97631_P49_094859.jpg'),
#              ('userRating', '5.31')])
# OrderedDict([('movieCd', '20190885'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183820'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1838/183820_P08_141424.jpg'),
#              ('userRating', '7.00')])
# OrderedDict([('movieCd', '20182387'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164125'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164125_P65_143635.jpg'),
#              ('userRating', '6.47')])
# OrderedDict([('movieCd', '20190466'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=137865'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1378/137865_P17_113027.jpg'),
#              ('userRating', '8.89')])
# OrderedDict([('movieCd', '19880001'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=18781'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0187/18781_P40_110031.jpg'),
#              ('userRating', '9.26')])
# OrderedDict([('movieCd', '20191401'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167053'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1670/167053_P13_111013.jpg'),
#              ('userRating', '8.54')])
# OrderedDict([('movieCd', '20198291'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181704'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1817/181704_P35_105923.jpg'),
#              ('userRating', '8.13')])
# OrderedDict([('movieCd', '20184889'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=136900'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1369/136900_P57_104126.jpg'),
#              ('userRating', '9.39')])
# OrderedDict([('movieCd', '20188941'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=177967'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1779/177967_P50_114447.jpg'),
#              ('userRating', '7.93')])
# OrderedDict([('movieCd', '20184865'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=137327'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1373/137327_P17_171853.jpg'),
#              ('userRating', '7.25')])
# OrderedDict([('movieCd', '20199063'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183870'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1838/183870_P25_095540.jpg'),
#              ('userRating', '8.05')])
# OrderedDict([('movieCd', '20188144'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=177371'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1773/177371_P20_114332.jpg'),
#              ('userRating', '5.05')])
# OrderedDict([('movieCd', '20184082'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=186899'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1868/186899_P01_111320.jpg'),
#              ('userRating', '10.00')])
# OrderedDict([('movieCd', '20199448'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180169'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1801/180169_P64_101528.jpg'),
#              ('userRating', '9.01')])
# OrderedDict([('movieCd', '20198597'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183132'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1831/183132_P05_134901.jpg'),
#              ('userRating', '9.28')])
# OrderedDict([('movieCd', '20199822'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181701'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1817/181701_P09_111143.jpg'),
#              ('userRating', '4.95')])
# OrderedDict([('movieCd', '20187981'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=177483'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1774/177483_P122_133507.jpg'),
#              ('userRating', '8.91')])
# OrderedDict([('movieCd', '20198598'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167657'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167657_P03_163928.jpg'),
#              ('userRating', '8.12')])
# OrderedDict([('movieCd', '20185784'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=175366'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1753/175366_P31_101140.jpg'),
#              ('userRating', '8.90')])
# OrderedDict([('movieCd', '20198183'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183136'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1831/183136_P10_134628.jpg'),
#              ('userRating', '9.28')])
# OrderedDict([('movieCd', '20185384'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=165022'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1650/165022_P15_153454.jpg'),
#              ('userRating', '9.11')])
# OrderedDict([('movieCd', '20197503'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=151550'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1515/151550_P22_095949.jpg'),
#              ('userRating', '6.87')])
# OrderedDict([('movieCd', '20197147'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=182012'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1820/182012_P08_135215.jpg'),
#              ('userRating', '9.18')])
# OrderedDict([('movieCd', '20169323'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=148863'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1488/148863_P10_094956.jpg'),
#              ('userRating', '8.35')])
# OrderedDict([('movieCd', '20183096'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174050'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1740/174050_P32_172314.jpg'),
#              ('userRating', '7.15')])
# OrderedDict([('movieCd', '20181877'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=132623'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1326/132623_P22_133853.jpg'),
#              ('userRating', '6.74')])
# OrderedDict([('movieCd', '20060347'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=49336'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0493/49336_P59_105053.jpg'),
#              ('userRating', '7.90')])
# OrderedDict([('movieCd', '20199736'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=184253'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1842/184253_P10_155905.jpg'),
#              ('userRating', '8.86')])
# OrderedDict([('movieCd', '20183454'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180399'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180399_P00_154546.jpg'),
#              ('userRating', '6.90')])
# OrderedDict([('movieCd', '20180825'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171785'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1717/171785_P84_181225.jpg'),
#              ('userRating', '8.31')])
# OrderedDict([('movieCd', '20198982'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=159845'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1598/159845_P12_102707.jpg'),
#              ('userRating', '8.84')])
# OrderedDict([('movieCd', '19990220'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=24830'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0248/24830_P18_133358.jpg'),
#              ('userRating', '9.07')])
# OrderedDict([('movieCd', '20176103'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=185267'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1852/185267_P03_110346.jpg'),
#              ('userRating', '7.42')])
# OrderedDict([('movieCd', '20198104'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168045'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168045_P15_100136.jpg'),
#              ('userRating', '8.47')])
# OrderedDict([('movieCd', '20185406'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164200'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1642/164200_P05_105455.jpg'),
#              ('userRating', '6.88')])
# OrderedDict([('movieCd', '20182501'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=173667'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1736/173667_P27_101947.jpg'),
#              ('userRating', '5.30')])
# OrderedDict([('movieCd', '20198844'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=183063'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1830/183063_P01_142452.jpg'),
#              ('userRating', '0.00')])
# OrderedDict([('movieCd', '20196244'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=140649'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1406/140649_P11_111034.jpg'),
#              ('userRating', '5.84')])
# OrderedDict([('movieCd', '20185352'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181414'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1814/181414_P24_174349.jpg'),
#              ('userRating', '6.82')])
# OrderedDict([('movieCd', '20197423'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181419'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1814/181419_P28_165542.jpg'),
#              ('userRating', '4.86')])
# OrderedDict([('movieCd', '20183773'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180381'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180381_P17_103533.jpg'),
#              ('userRating', '8.27')])
# OrderedDict([('movieCd', '20198403'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181912'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1819/181912_P10_135327.jpg'),
#              ('userRating', '8.98')])
# OrderedDict([('movieCd', '20196025'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=163787'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1637/163787_P33_174808.jpg'),
#              ('userRating', '8.94')])
# OrderedDict([('movieCd', '20197092'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=182348'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1823/182348_P02_174720.jpg'),
#              ('userRating', '9.30')])
# OrderedDict([('movieCd', '20198146'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171533'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1715/171533_P29_143351.jpg'),
#              ('userRating', '8.67')])
# OrderedDict([('movieCd', '20197846'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=153580'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1535/153580_P24_103637.jpg'),
#              ('userRating', '5.78')])
# OrderedDict([('movieCd', '20175407'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=161984'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1619/161984_P61_144815.jpg'),
#              ('userRating', '3.94')])
# OrderedDict([('movieCd', '20166301'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=152624'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1526/152624_P34_161443.jpg'),
#              ('userRating', '5.93')])
# OrderedDict([('movieCd', '20197483'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=182407'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1824/182407_P00_105405.jpg'),
#              ('userRating', '8.29')])
# OrderedDict([('movieCd', '20197283'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180425'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1804/180425_P19_175210.jpg'),
#              ('userRating', '7.63')])
# OrderedDict([('movieCd', '20197356'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=179974'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1799/179974_P01_153621.jpg'),
#              ('userRating', '8.82')])
# OrderedDict([('movieCd', '20198603'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=169263'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1692/169263_P01_094955.jpg'),
#              ('userRating', '7.93')])
# OrderedDict([('movieCd', '20197617'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=149022'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1490/149022_P12_110503.jpg'),
#              ('userRating', '6.94')])
# OrderedDict([('movieCd', '20184574'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171539'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1715/171539_P26_135622.jpg'),
#              ('userRating', '9.61')])
# OrderedDict([('movieCd', '20196601'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=182360'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1823/182360_P11_140223.jpg'),
#              ('userRating', '8.59')])
# OrderedDict([('movieCd', '20182530'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167651'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167651_P106_141030.jpg'),
#              ('userRating', '8.53')])
# OrderedDict([('movieCd', '20185881'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=177374'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1773/177374_P100_112832.jpg'),
#              ('userRating', '9.07')])
# OrderedDict([('movieCd', '20177539'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167099'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1670/167099_P13_101134.jpg'),
#              ('userRating', '7.20')])
# OrderedDict([('movieCd', '20196723'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=182206'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1822/182206_P12_121114.jpg'),
#              ('userRating', '8.63')])
# OrderedDict([('movieCd', '20180937'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=148909'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1489/148909_P29_164758.jpg'),
#              ('userRating', '8.77')])
# OrderedDict([('movieCd', '20177282'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=170953'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1709/170953_P08_140411.jpg'),
#              ('userRating', '8.10')])
# OrderedDict([('movieCd', '20176442'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=159070'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1590/159070_P13_114738.jpg'),
#              ('userRating', '3.84')])
# OrderedDict([('movieCd', '20195743'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181959'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1819/181959_P11_114544.jpg'),
#              ('userRating', '6.37')])
# OrderedDict([('movieCd', '20195791'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167629'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167629_P17_105046.jpg'),
#              ('userRating', '4.50')])
# OrderedDict([('movieCd', '20186261'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=109193'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1091/109193_P21_103935.jpg'),
#              ('userRating', '9.24')])
# OrderedDict([('movieCd', '20188282'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=66728'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0667/66728_P38_102726.jpg'),
#              ('userRating', '8.71')])
# OrderedDict([('movieCd', '20195915'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181411'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1814/181411_P02_101349.jpg'),
#              ('userRating', '7.39')])
# OrderedDict([('movieCd', '20020222'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=33930'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0339/C3930-06.jpg'),
#              ('userRating', '8.86')])
# OrderedDict([('movieCd', '20185576'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181409'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1814/181409_P30_100656.jpg'),
#              ('userRating', '6.58')])
# OrderedDict([('movieCd', '20184888'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=151151'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1511/151151_P24_105029.jpg'),
#              ('userRating', '8.18')])
# OrderedDict([('movieCd', '20174169'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=169078'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1690/169078_P66_101231.jpg'),
#              ('userRating', '5.89')])
# OrderedDict([('movieCd', '20180868'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164173'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164173_P45_171744.jpg'),
#              ('userRating', '6.08')])
# OrderedDict([('movieCd', '20162003'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=48233'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0482/48233_P05_140218.jpg'),
#              ('userRating', '8.29')])
# OrderedDict([('movieCd', '20185478'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=181554'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1815/181554_P23_112202.jpg'),
#              ('userRating', '8.75')])
# OrderedDict([('movieCd', '20185444'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=125438'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1254/125438_P06_114959.jpg'),
#              ('userRating', '8.73')])
# OrderedDict([('movieCd', '20184105'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167699'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167699_P40_175859.jpg'),
#              ('userRating', '9.07')])
# OrderedDict([('movieCd', '20185124'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180220'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1802/180220_P01_102406.jpg'),
#              ('userRating', '9.28')])
# OrderedDict([('movieCd', '20184896'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174830'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1748/174830_P17_104205.jpg'),
#              ('userRating', '9.59')])
# OrderedDict([('movieCd', '20176251'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164172'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164172_P08_114039.jpg'),
#              ('userRating', '8.19')])
# OrderedDict([('movieCd', '20189463'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=152632'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1526/152632_P19_104759.jpg'),
#              ('userRating', '8.68')])
# OrderedDict([('movieCd', '20182544'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=163826'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1638/163826_P07_174644.jpg'),
#              ('userRating', '7.40')])
# OrderedDict([('movieCd', '20186324'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=144318'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1443/144318_P19_100103.jpg'),
#              ('userRating', '9.31')])
# OrderedDict([('movieCd', '20185485'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=156464'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1564/156464_P49_182103.jpg'),
#              ('userRating', '9.42')])
# OrderedDict([('movieCd', '20189385'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168056'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168056_P10_100606.jpg'),
#              ('userRating', '7.19')])
# OrderedDict([('movieCd', '20180290'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=151153'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1511/151153_P19_095147.jpg'),
#              ('userRating', '8.35')])
# OrderedDict([('movieCd', '20183915'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180372'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180372_P16_101254.jpg'),
#              ('userRating', '9.14')])
# OrderedDict([('movieCd', '20182588'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172137'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1721/172137_P12_134909.jpg'),
#              ('userRating', '6.05')])
# OrderedDict([('movieCd', '20186281'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164139'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164139_P12_153521.jpg'),
#              ('userRating', '8.09')])
# OrderedDict([('movieCd', '20170658'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=166092'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1660/166092_P35_104446.jpg'),
#              ('userRating', '5.21')])
# OrderedDict([('movieCd', '20175547'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164101'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164101_P62_155759.jpg'),
#              ('userRating', '8.36')])
# OrderedDict([('movieCd', '20183785'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180379'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180379_P32_111508.jpg'),
#              ('userRating', '9.13')])
# OrderedDict([('movieCd', '20184187'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=187444'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1874/187444_P01_113615.jpg'),
#              ('userRating', '8.33')])
# OrderedDict([('movieCd', '20182421'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=150688'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1506/150688_P30_101919.jpg'),
#              ('userRating', '8.33')])
# OrderedDict([('movieCd', '20168773'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=157297'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1572/157297_P23_134212.jpg'),
#              ('userRating', '6.33')])
# OrderedDict([('movieCd', '20183479'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172975'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1729/172975_P10_141815.jpg'),
#              ('userRating', '8.29')])
# OrderedDict([('movieCd', '20183238'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171725'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1717/171725_P18_175530.jpg'),
#              ('userRating', '9.21')])
# OrderedDict([('movieCd', '20177552'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164192'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164192_P45_134107.jpg'),
#              ('userRating', '8.16')])
# OrderedDict([('movieCd', '20179230'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171755'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1717/171755_P39_140011.jpg'),
#              ('userRating', '6.01')])
# OrderedDict([('movieCd', '20183375'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172187'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1721/172187_P19_110125.jpg'),
#              ('userRating', '8.97')])
# OrderedDict([('movieCd', '20189843'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=158622'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1586/158622_P18_142307.jpg'),
#              ('userRating', '7.16')])
# OrderedDict([('movieCd', '20182082'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171452'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1714/171452_P19_174244.jpg'),
#              ('userRating', '7.81')])
# OrderedDict([('movieCd', '20178825'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=156496'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1564/156496_P24_153246.jpg'),
#              ('userRating', '6.15')])
# OrderedDict([('movieCd', '20183745'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180384'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180384_P14_152246.jpg'),
#              ('userRating', '7.73')])
# OrderedDict([('movieCd', '20177538'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167638'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167638_P71_133542.jpg'),
#              ('userRating', '8.63')])
# OrderedDict([('movieCd', '20184481'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174835'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1748/174835_P26_105639.jpg'),
#              ('userRating', '7.52')])
# OrderedDict([('movieCd', '20181905'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=182650'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1826/182650_P01_181030.jpg'),
#              ('userRating', '0.00')])
# OrderedDict([('movieCd', '20176814'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=154255'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1542/154255_P24_095824.jpg'),
#              ('userRating', '6.18')])
# OrderedDict([('movieCd', '20183073'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=144906'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1449/144906_P15_103017.jpg'),
#              ('userRating', '9.53')])
# OrderedDict([('movieCd', '20181171'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=173692'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1736/173692_P12_102159.jpg'),
#              ('userRating', '9.17')])
# OrderedDict([('movieCd', '20183007'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=161868'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1618/161868_P24_151256.jpg'),
#              ('userRating', '7.88')])
# OrderedDict([('movieCd', '20182966'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=179138'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1791/179138_P01_151818.jpg'),
#              ('userRating', '4.54')])
# OrderedDict([('movieCd', '20183050'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=176354'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1763/176354_P13_150227.jpg'),
#              ('userRating', '9.31')])
# OrderedDict([('movieCd', '20182935'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=186453'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1864/186453_P03_141045.jpg'),
#              ('userRating', '0.00')])
# OrderedDict([('movieCd', '20182669'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=154653'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1546/154653_P12_102646.jpg'),
#              ('userRating', '8.84')])
# OrderedDict([('movieCd', '20186822'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=175318'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1753/175318_P15_105507.jpg'),
#              ('userRating', '8.25')])
# OrderedDict([('movieCd', '20170513'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=166610'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1666/166610_P58_154049.jpg'),
#              ('userRating', '5.33')])
# OrderedDict([('movieCd', '20189869'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164147'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164147_P46_165808.jpg'),
#              ('userRating', '7.49')])
# OrderedDict([('movieCd', '20174981'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=160487'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1604/160487_P48_113750.jpg'),
#              ('userRating', '5.07')])
# OrderedDict([('movieCd', '20010291'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=30688'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/0306/30688_P28_142632.jpg'),
#              ('userRating', '9.22')])
# OrderedDict([('movieCd', '20179006'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171750'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1717/171750_P05_173050.jpg'),
#              ('userRating', '4.21')])
# OrderedDict([('movieCd', '20181404'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164155'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164155_P03_122329.jpg'),
#              ('userRating', '6.03')])
# OrderedDict([('movieCd', '20180523'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168050'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168050_P19_100458.jpg'),
#              ('userRating', '9.15')])
# OrderedDict([('movieCd', '20182693'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172819'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1728/172819_P01_163303.jpg'),
#              ('userRating', '7.39')])
# OrderedDict([('movieCd', '20180987'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=170879'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1708/170879_P03_161546.jpg'),
#              ('userRating', '6.30')])
# OrderedDict([('movieCd', '20179189'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167105'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1671/167105_P28_103614.jpg'),
#              ('userRating', '8.32')])
# OrderedDict([('movieCd', '20189067'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=155356'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1553/155356_P29_104216.jpg'),
#              ('userRating', '9.10')])
# OrderedDict([('movieCd', '20182403'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168047'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168047_P06_140254.jpg'),
#              ('userRating', '7.05')])
# OrderedDict([('movieCd', '20186321'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168058'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168058_P18_101211.jpg'),
#              ('userRating', '6.95')])
# OrderedDict([('movieCd', '20177221'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=119428'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1194/119428_P08_114709.jpg'),
#              ('userRating', '7.90')])
# OrderedDict([('movieCd', '20189123'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168023'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168023_P15_161116.jpg'),
#              ('userRating', '8.95')])
# OrderedDict([('movieCd', '20176122'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=163533'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1635/163533_P99_105455.jpg'),
#              ('userRating', '8.00')])
# OrderedDict([('movieCd', '20184678'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174807'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1748/174807_P19_111000.jpg'),
#              ('userRating', '5.35')])
# OrderedDict([('movieCd', '20187521'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=177381'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1773/177381_P01_144141.jpg'),
#              ('userRating', '6.63')])
# OrderedDict([('movieCd', '20180628'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167481'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1674/167481_P05_145414.jpg'),
#              ('userRating', '7.03')])
# OrderedDict([('movieCd', '20180770'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=178402'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1784/178402_P16_115047.jpg'),
#              ('userRating', '5.15')])
# OrderedDict([('movieCd', '20189462'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=158620'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1586/158620_P19_101107.jpg'),
#              ('userRating', '8.51')])
# OrderedDict([('movieCd', '20177308'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164106'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164106_P16_135532.jpg'),
#              ('userRating', '7.36')])
# OrderedDict([('movieCd', '20188661'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=170824'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1708/170824_P15_182407.jpg'),
#              ('userRating', '7.53')])
# OrderedDict([('movieCd', '20172204'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=162981'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1629/162981_P72_153440.jpg'),
#              ('userRating', '7.06')])
# OrderedDict([('movieCd', '20167903'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=152156'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1521/152156_P76_134247.jpg'),
#              ('userRating', '6.63')])
# OrderedDict([('movieCd', '20189262'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168049'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168049_P02_145901.jpg'),
#              ('userRating', '6.67')])
# OrderedDict([('movieCd', '20185046'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=184543'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1845/184543_P01_155230.png'),
#              ('userRating', '0.00')])
# OrderedDict([('movieCd', '20188304'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=170496'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1704/170496_P19_142149.jpg'),
#              ('userRating', '8.84')])
# OrderedDict([('movieCd', '20189268'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=185166'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1851/185166_P01_162115.jpg'),
#              ('userRating', '0.00')])
# OrderedDict([('movieCd', '20180167'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=178426'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1784/178426_P18_102633.jpg'),
#              ('userRating', '5.33')])
# OrderedDict([('movieCd', '20189746'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=178445'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1784/178445_P01_100308.jpg'),
#              ('userRating', '9.00')])
# OrderedDict([('movieCd', '20156554'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=132996'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1329/132996_P35_100121.jpg'),
#              ('userRating', '4.82')])
# OrderedDict([('movieCd', '20153446'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=140652'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1406/140652_P38_143110.jpg'),
#              ('userRating', '8.42')])
# OrderedDict([('movieCd', '20188581'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=127335'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1273/127335_P10_172314.jpg'),
#              ('userRating', '5.82')])
# OrderedDict([('movieCd', '20189362'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174626'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1746/174626_P11_140653.jpg'),
#              ('userRating', '9.02')])
# OrderedDict([('movieCd', '20177537'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172010'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1720/172010_P10_141651.jpg'),
#              ('userRating', '4.25')])
# OrderedDict([('movieCd', '20181942'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164115'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164115_P50_104521.jpg'),
#              ('userRating', '8.96')])
# OrderedDict([('movieCd', '20186202'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167697'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167697_P01_113354.jpg'),
#              ('userRating', '7.71')])
# OrderedDict([('movieCd', '20179101'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=153687'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1536/153687_P54_102718.jpg'),
#              ('userRating', '6.85')])
# OrderedDict([('movieCd', '20170670'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=153642'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1536/153642_P102_113909.jpg'),
#              ('userRating', '7.79')])
# OrderedDict([('movieCd', '20189261'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172768'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1727/172768_P23_140008.jpg'),
#              ('userRating', '8.73')])
# OrderedDict([('movieCd', '20187647'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167602'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167602_P09_101816.jpg'),
#              ('userRating', '7.91')])
# OrderedDict([('movieCd', '20181181'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=154222'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1542/154222_P07_114856.jpg'),
#              ('userRating', '9.12')])
# OrderedDict([('movieCd', '20139221'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180901'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1809/180901_P01_161910.jpg'),
#              ('userRating', '0.00')])
# OrderedDict([('movieCd', '20184802'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=169643'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1696/169643_P26_103310.jpg'),
#              ('userRating', '8.59')])
# OrderedDict([('movieCd', '20183584'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=152661'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1526/152661_P02_173353.jpg'),
#              ('userRating', '5.87')])
# OrderedDict([('movieCd', '20187657'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171499'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1714/171499_P38_160259.jpg'),
#              ('userRating', '7.41')])
# OrderedDict([('movieCd', '20187641'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172118'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1721/172118_P13_110330.jpg'),
#              ('userRating', '8.76')])
# OrderedDict([('movieCd', '20187427'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=173019'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1730/173019_P30_150613.jpg'),
#              ('userRating', '9.07')])
# OrderedDict([('movieCd', '20186501'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=175727'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1757/175727_P08_154401.jpg'),
#              ('userRating', '9.23')])
# OrderedDict([('movieCd', '20183361'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=136990'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1369/136990_P27_140604.jpg'),
#              ('userRating', '9.23')])
# OrderedDict([('movieCd', '20185242'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174805'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1748/174805_P12_100714.jpg'),
#              ('userRating', '8.72')])
# OrderedDict([('movieCd', '20186121'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172174'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1721/172174_P20_110537.jpg'),
#              ('userRating', '9.21')])
# OrderedDict([('movieCd', '20170942'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=109906'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1099/109906_P00_103901.jpg'),
#              ('userRating', '3.85')])
# OrderedDict([('movieCd', '20180522'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=144330'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1443/144330_P05_110325.jpg'),
#              ('userRating', '8.62')])
# OrderedDict([('movieCd', '20185341'),
#              ('link',
#               'https://movie.naver.com/movie/bi/mi/basic.nhn?code=186657'),
#              ('image',
#               'https://ssl.pstatic.net/imgmovie/mdi/mit110/1866/186657_P01_113547.jpg'),
#              ('userRating', '10.00')])
# movie_naver.csv 186개의 행

# %% [markdown]
# 2. 영화 포스터 이미지 저장 `movie_image.py`
# * `movie_naver.py`에서 받아온 이미지 url에 요청을 보내 실제 이미지 파일로 저장. 향후 영화 포스터 이미지로 사용될 것
#
#
#     * 요청
#         * 영화 썸네일 이미지 URL
#
#
#     *  응답
#         * 응답 결과 파일로 저장하기. 반드시 `wb`옵션으로 저장하기.
#         * 저장되는 파일명은 `images`폴더 내에 `영진위 영화 대표코드.jpg`
#
#
# [소스보기](./movie_image.py)

# %%
# movie_image.py

import requests

# 인터넷 상의 이미지파일
url = 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1590/159070_P13_114738.jpg'

# 요청 -> 파일 저장
# wb : 바이너리 파일을 쓰겠다.
with open('./images/test.jpg', 'wb') as f:
    response = requests.get(url)
    print(response.content)
    f.write(response.content) 
    # 텍스트형식(json, html, xml...)이 아닌 
    # 바이너리 형식을 받을 때는 .content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff\xec\x00\x11Ducky\x00\x01\x00\x04\x00\x00\x00\x1e\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x00\x9d\x00n\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1c\x00\x00\x02\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x03\x06\x07\x02\x01\x00\x08\xff\xc4\x00;\x10\x00\x02\x01\x02\x04\x04\x04\x04\x03\x07\x04\x02\x03\x00\x00\x00\x01\x02\x03\x04\x11\x00\x05\x12!\x06\x131A"Qaq\x07\x14\x81\x91#2B\x153R\xa1\xc1\xd1\xf0\x16$\x82\xb1b\xe1C\x92\xa3\xff\xc4\x00\x18\x01\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x00\x04\xff\xc4\x00 \x11\x00\x02\x02\x03\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03\x12!1AQ\x13"\x04\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xd4\x16i\xf5^\xc6\xf8>\x9a\xb6D\xd9\x85\xf0\xc8SB\xbb\x84\x18\xf5\xe2\x8c\x0b\xf2\xc7\xdb\x14sO\xd1\xcf\x1cm{\x07\x15e\x85\xad{\xe1}LQ\xb1\xd9\x06\xabu\xc33\x05\xc7\x80\x0b\xfb`)\xa2\x98\xa9\xd0\x14H\x0f\xea\x06\xd8\xd1\x92\x8fPe\x07.0\x11\x11\xc1\x14\xec\xb18\xf2\xc7F*\xb2n\xdc\x95\x8f\x99\xb9;x{o\xe7\x88\x9e\n\xc8\xda\xcc\xb1\x80X\x9b\xff\x00\xe3\xdb\r\xfb)r\x85\xfc\x1cz\x9a\x1b\xbcbxvn\xd8\x0f\xe4\\\x0b\xdb\x1cC-X0\xa80\x83\xbf0\x1d\xaf\xb7\x86\xdf\\\x17\x08\xae#\xf1L\x1f\xba\xec\x0f\xef?\xb6!\xbbN\xa8\xbf\xe6\xa4\xae\xd1\x12\xd1\xb8m\xc6\x08Zb\x06\xf8\x8d\xdf1\x1e\x10\xd4\xfa\xf4\r\xac\x7f5\xf7\xfaZ\xf8\xeaCZ\xcf\'(\xc0\x12\xcb\xa0\xb5\xef~\xf7\xc0y\x1b\xf42\xc4\x97\xb4w\xa0(\xdf\x1exN\xd8\x92`\xd6\xe8m\xed\x81\xd8\xe9\xc1\x10\xf6D\x01.\x06\x02s\xbe\x0c/u\xc4f5m\xf0\xf1u\xe4I+\xf00\x90\r\x1dlz\x83\x8c\x03\x88\xa9\xf2\xcc\xbb\x8b\xab\xe0c]=\x0cRZ\xa3MI\x0f\xa9\x85\xda\xccE\x80\x04\xf4\xb7\xe98\xd3\xa6\xe2\n*Z\xf8\xe2^y\x8c9Y%.\xca\x87I\xb3h^\xe1O\xe6sd\x1b\xf8\x89\xdb\n_\xe1\xed\x1c\xd9feO>iQ$\xb9\x84\xeb9\xa90\x8f\r\x89k\x00:\x83\xa8\xf7\xc73\x95\xa3\xa9F\x99[\xcc\xc0\xa5\xe2\x9e,\xa4\x10UT\xd1|\x8cq\xfe\x0c\xc4:\xe9\x11r\xcd\xfdM\xae|\xaf\x85y~K\x99e\xb4\xcbU=\x05c\xcfQE,\xf4\xf5Bwhb\x05\x18i\x91@ \x1bj\xef\xb1+\xeb\x8b\xc4\xdc\x06_\xf6\xb99\xaf8\xe6T\x91R3\x18lSF\x8b1\x17\xde\xfa:mk\xe3\xaa>\x0e\xe2J\x1a8)(\xb8\xaa\xaa\x96\x9a(\xc2$Q\xd3)\x0bn\xbf\xab\xb9\xb9\xfa\xe3XJ\x0eiI\x1bp7\x0eI\xaa\xad\xeb\xaa\x8c\xb1,.\xe7G-dc\xa8\xa7v\xbb\x01|\x1b4\xb4\xe3$\xe1J\xac\xa1k%w\xcd$&\n\x9a\x9dldS\x1a\x85\xd4\x00\x01M\x81\xf4\xbe4*^\x0c\x91\xb3\xac\xaf5\xcd\xf3\xaa\x9c\xc2\xa2\x862\xa0K\x10UrK\x1b\x9b\x1d\xad\xab\xa7\xa0\xc2\xbaO\x87\x14\xd4\x95t4t\xf9\xd4\x8e(+?ir\x8d0\xd8\x12\xa0%\xefa}\x1e\xfdv\xc1\xa0Z3\x9c\xfa\t\xdf=\xad\x95\xa1\xade\x9aw&J\xaav\xe6\xc7\xe26\xd25X\x8bl:ml\\\xf8\x18V\xd4q=t\xf4\xb5\x15(\x82\x83\x94^\xa5n\xce\xe0*\xa9cr\x01\x04^\xd7;[\x04f\x9f\x0be\xad\xce+\xf3\x08\xb3h\n\xd5Je1\xd6RsJ\x12o\xb1\xd5\xf4\xf6\xc3\xae\r\xe0\xe6\xe1Y\xaa\xa7z\xf1P\xf3\xaa\xaf.(\xf9q\xad\x8d\xef\xa6\xe7~\xde\xd8h\xc5\xed\xd1%5\xaf\x0c\xa6<\x9f5\xe7\xacf\x16L\xdcTj|\xcd\xb3T\xd07\xeb\xd7\xcf{\xde\xfe\x98.\xae\x96\xb7\xf66t+\xaa\xc1\x9al\xda&\x151\xabH\x932\x89K0\x11\x82@7\xb8\xd8\x0c[\xc7\xc2y\x15\x1c\xaee\x97\x92\xf2;\xde|\xb5e;\x9b\xd8\\\xff\x00\x97\xc3<\x97\xe1\xa6]G\x97\xd6Rf5\x06\xaa:\x99\xa3\x98\xad84\xe1Y\x03\x01m\'\xa7\x88\xed\xd3\x03F6\xe8\xcaj\xea\xaa\xeb\xa2\xa8\x82Y*\x94j\x05]\x9e\xa9\xd5\xb7\xdc\x857\xb0\xf7\x18i\xc4\xc4I\x9bOR\xb1K8\xf9*d\x8a9)\xe7\n\xc4D\x977\x16\xf5\xef\xef\x8d\x171\xf8]\x93Te\xd2\xc1\x96ISGS%\x879\xea$\x94\x05\xb8$i-\xe9\x80x\x87\xe1\xb4\xf9\xa6c\x1dZf\xe3\xc1O\x1c\x1c\xaa\xa8\x99\xd5t([\xad\x98Z\xf6\xbd\xbc\xce\x06\x8c\xdb\xa2\xb5\xf0\xf1W\xfdQG!\xa6\x11;G"\x90\xb4\xf5\x1e\x12T\xec]\x98\xafo\xed\x8d\x8bA\xc5\x1b\x84\xb8\x0e~\x1a\xce\xdb1\x975\x12\x03\x1b\'\xcb\xd3\xc6\xd1\xa1\xbf\x9d\xd8\xde\xdd}\xf1z\xe6\x81\x8aA4\x89di\xbe\t\xd7$\xa2\x9b45\xd3\x ...

# %%
# movie_naver.csv에서 url(image), 영진위 영화 대표코드 받아오기

# url, 영화 대표코드 저장할 리스트
image_list = []

with open('movie_naver.csv', 'r', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        url = row.get('image') if row.get('image') else None
        movieCd = row.get('movieCd')
        image_list.append((url, movieCd))
        break
    print(image_list)
    
for url, movieCd in image_list:
    #만약 url이 None이면 요청하지 않음
    # 이미지 파일 파이너리 형태로 저장
    if url:
        with open('./images/' + movieCd + '.jpg', 'wb') as f:
            response = requests.get(url)
            f.write(response.content)
# Out:
# [('https://ssl.pstatic.net/imgmovie/mdi/mit110/1731/173123_P06_135928.jpg', '20196309')]

# %% [markdown]
# movie_image.py 실행 결과 ./images 디렉토리에는 186개의 영화 포스터 이미지 파일이 생성됨.
